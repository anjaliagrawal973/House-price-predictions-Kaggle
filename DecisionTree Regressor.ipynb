# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train_final=pd.read_csv('X_train_fin.csv')
y_train_final=pd.read_csv('y_train_final.csv')

# %%
X_train_final.describe()
# Out:
#         MSSubClass      LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      0.038338     0.005563     0.003497     0.003138     0.024381
# std       0.029013     0.000355     0.000949     0.000763     0.020748
# min       0.013032     0.004232     0.000000     0.000000    -0.000686
# 25%       0.013032     0.005439     0.002743     0.002743     0.004801
# 50%       0.033608     0.005595     0.003429     0.002743     0.023320
# 75%       0.047325     0.005733     0.004115     0.003429     0.036351
# max       0.129630     0.007736     0.006173     0.005487     0.092593
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count   1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean       0.015055     0.070039     0.303594     0.031241     0.388368  ...
# std        0.014157     0.123958     0.312824     0.110644     0.303064  ...
# ...

# %%
X_train_final.shape
# Out:
# (1460, 26)

# %%
X_train_final.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal'],
#       dtype='object')

# %%
X_train_final.head()
# Out:
#    MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0    0.040466  0.005516     0.004115     0.002743   0.002743      0.002743
# 1    0.013032  0.005603     0.003429     0.004801   0.020576      0.020576
# 2    0.040466  0.005712     0.004115     0.002743   0.004115      0.003429
# 3    0.047325  0.005600     0.004115     0.002743   0.061728      0.024005
# 4    0.040466  0.005875     0.004801     0.002743   0.004801      0.004801
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  GarageYrBlt  \
# 0    0.133745    0.483539   -0.000686   0.102195  ...     0.002743
# 1   -0.000686    0.670096   -0.000686   0.194102  ...     0.020576
# 2    0.110425    0.332647   -0.000686   0.296982  ...     0.004115
# 3   -0.000686    0.147462   -0.000686   0.369684  ...     0.004801
# 4    0.239369    0.448560   -0.000686   0.335391  ...     0.004801
#
#    GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# ...

# %%
X_train_final
# Out:
#       MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0       0.040466  0.005516     0.004115     0.002743   0.002743      0.002743
# 1       0.013032  0.005603     0.003429     0.004801   0.020576      0.020576
# 2       0.040466  0.005712     0.004115     0.002743   0.004115      0.003429
# 3       0.047325  0.005600     0.004115     0.002743   0.061728      0.024005
# 4       0.040466  0.005875     0.004801     0.002743   0.004801      0.004801
# ...          ...       ...          ...          ...        ...           ...
# 1455    0.040466  0.005471     0.003429     0.002743   0.004801      0.004115
# 1456    0.013032  0.005820     0.003429     0.003429   0.021262      0.014403
# 1457    0.047325  0.005562     0.004115     0.005487   0.046639      0.002058
# 1458    0.013032  0.005612     0.002743     0.003429   0.040466      0.008916
# 1459    0.013032  0.005627     0.002743     0.003429   0.028807      0.028807
#
# ...

# %%
y_train_final.describe()
# Out:
#          SalePrice
# count  1460.000000
# mean     12.024051
# std       0.399452
# min      10.460242
# 25%      11.775097
# 50%      12.001505
# 75%      12.273731
# max      13.534473

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Define model
model = DecisionTreeRegressor()

#Fit the model
model.fit(X_train_final,y_train_final)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
print("Making predictions for the following 5 houses")
print(X_train_final.head())
# Out:
# Making predictions for the following 5 houses
#    MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0    0.040466  0.005516     0.004115     0.002743   0.002743      0.002743
# 1    0.013032  0.005603     0.003429     0.004801   0.020576      0.020576
# 2    0.040466  0.005712     0.004115     0.002743   0.004115      0.003429
# 3    0.047325  0.005600     0.004115     0.002743   0.061728      0.024005
# 4    0.040466  0.005875     0.004801     0.002743   0.004801      0.004801
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  GarageYrBlt  \
# 0    0.133745    0.483539   -0.000686   0.102195  ...     0.002743
# 1   -0.000686    0.670096   -0.000686   0.194102  ...     0.020576
# 2    0.110425    0.332647   -0.000686   0.296982  ...     0.004115
# 3   -0.000686    0.147462   -0.000686   0.369684  ...     0.004801
# 4    0.239369    0.448560   -0.000686   0.335391  ...     0.004801
#
# ...

# %%
from sklearn.metrics import mean_absolute_error

# %%
predicted_prices = model.predict(X_train_final)
mean_absolute_error(y_train_final,predicted_prices)
# Out:
# 0.00011289778089755112

# %%
from sklearn.model_selection import train_test_split

# %%
train_X,test_X,train_y,test_y = train_test_split(X_train_final,X_train_final,random_state= 0)

# %%
#Define Model
model_1 = DecisionTreeRegressor()
# Fit the model
model_1.fit(train_X,train_y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
predicted_prices_1 = model_1.predict(test_X)

# %%
print(mean_absolute_error(test_y,predicted_prices_1))
# Out:
# 0.021180577852054253

# %% [markdown]
# But the max_leaf_nodes argument provides a very sensible way to control overfitting vs underfitting.

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

# %%
# Defined a function to calculate mae
def get_mae(max_leaf_nodes, train_X, train_y,test_X, test_y):
    model_2 = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes,random_state=454)
    model_2.fit(train_X,train_y)
    pred_y = model_2.predict(test_X)
    mae = mean_absolute_error(test_y,pred_y)
    return mae

# %%
for max_leaves in [2,3,5,50,150,200,250,300,500,1000,3000,5000,18000,50000]:
    my_mae = get_mae(max_leaves,train_X,train_y,test_X,test_y)
    print("max leaf nodes : %d \t and Mean Absolute error : %d"%(max_leaves,my_mae))
# Out:
# max leaf nodes : 2 	 and Mean Absolute error : 0
# max leaf nodes : 3 	 and Mean Absolute error : 0
# max leaf nodes : 5 	 and Mean Absolute error : 0
# max leaf nodes : 50 	 and Mean Absolute error : 0
# max leaf nodes : 150 	 and Mean Absolute error : 0
# max leaf nodes : 200 	 and Mean Absolute error : 0
# max leaf nodes : 250 	 and Mean Absolute error : 0
# max leaf nodes : 300 	 and Mean Absolute error : 0
# max leaf nodes : 500 	 and Mean Absolute error : 0
# max leaf nodes : 1000 	 and Mean Absolute error : 0
# max leaf nodes : 3000 	 and Mean Absolute error : 0
# max leaf nodes : 5000 	 and Mean Absolute error : 0
# max leaf nodes : 18000 	 and Mean Absolute error : 0
# max leaf nodes : 50000 	 and Mean Absolute error : 0

# %%
test=pd.read_csv('X_test_fin.csv')

# %%
test.shape
# Out:
# (1459, 26)

# %%
print("Making predictions for all")
print(test.head())
# Out:
# Making predictions for all
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0      1461.0   1461.0       1461.0       1461.0     1461.0        1461.0
# 1      1462.0   1462.0       1462.0       1462.0     1462.0        1462.0
# 2      1463.0   1463.0       1463.0       1463.0     1463.0        1463.0
# 3      1464.0   1464.0       1464.0       1464.0     1464.0        1464.0
# 4      1465.0   1465.0       1465.0       1465.0     1465.0        1465.0
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  GarageYrBlt  \
# 0      1461.0      1461.0      1461.0     1461.0  ...       1461.0
# 1      1462.0      1462.0      1462.0     1462.0  ...       1462.0
# 2      1463.0      1463.0      1463.0     1463.0  ...       1463.0
# 3      1464.0      1464.0      1464.0     1464.0  ...       1464.0
# 4      1465.0      1465.0      1465.0     1465.0  ...       1465.0
#
#    GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# ...

# %% [markdown]
# PREDICTING ONLY FOR HEAD
#
# print("The predicted values are")
# y_pred1=model.predict(test.head())
# print(y_pred1)

# %%
print("The predicted values are")
y_pred1=model.predict(test)
print(y_pred1)
# Out:
# The predicted values are
# [13.53447303 13.53447303 13.53447303 ... 13.53447303 13.53447303
#  13.53447303]

# %% [markdown]
# # -PART 2-

# %%
test_y
# Out:
#       MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 529     0.013032  0.006443     0.003429     0.001372   0.033608      0.021262
# 491     0.033608  0.005595     0.003429     0.004115   0.043896      0.037723
# 459     0.033608  0.005388     0.002743     0.002058   0.039781      0.039781
# 279     0.040466  0.005632     0.004115     0.002743   0.020576      0.020576
# 655     0.109053  0.004408     0.003429     0.002743   0.026063      0.026063
# ...          ...       ...          ...          ...        ...           ...
# 583     0.050754  0.005837     0.006173     0.005487   0.078189      0.004801
# 1245    0.054184  0.005761     0.003429     0.004115   0.015089      0.002058
# 1390    0.013032  0.005567     0.004115     0.002743   0.003429      0.003429
# 1375    0.013032  0.005696     0.004801     0.002743  -0.000686     -0.000686
# 638     0.019890  0.005542     0.002743     0.004115   0.066529      0.039095
#
# ...

# %%
y_pred1
# Out:
# array([13.53447303, 13.53447303, 13.53447303, ..., 13.53447303,
#        13.53447303, 13.53447303])

# %%
#df=pd.DataFrame({'Actual':[test_y], 'Predicted':[y_pred1]})
#df

# %%
#print({'Actual':[test_y], 'Predicted':[y_pred1]})

# %%
col = pd.Series(np.array(y_pred1))
test_y= test_y.assign(y_pred=col)

# %%
test_y
# Out:
#       MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 529     0.013032  0.006443     0.003429     0.001372   0.033608      0.021262
# 491     0.033608  0.005595     0.003429     0.004115   0.043896      0.037723
# 459     0.033608  0.005388     0.002743     0.002058   0.039781      0.039781
# 279     0.040466  0.005632     0.004115     0.002743   0.020576      0.020576
# 655     0.109053  0.004408     0.003429     0.002743   0.026063      0.026063
# ...          ...       ...          ...          ...        ...           ...
# 583     0.050754  0.005837     0.006173     0.005487   0.078189      0.004801
# 1245    0.054184  0.005761     0.003429     0.004115   0.015089      0.002058
# 1390    0.013032  0.005567     0.004115     0.002743   0.003429      0.003429
# 1375    0.013032  0.005696     0.004801     0.002743  -0.000686     -0.000686
# 638     0.019890  0.005542     0.002743     0.004115   0.066529      0.039095
#
# ...

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(test_y, y_pred1))
print('Mean Squared Error:', metrics.mean_squared_error(test_y, y_pred1))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_y, y_pred1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-fba3f8fcc4a3> in <module>
#       1 from sklearn import metrics
#       2
# ----> 3 print('Mean Absolute Error:', metrics.mean_absolute_error(test_y, y_pred1))
#       4 print('Mean Squared Error:', metrics.mean_squared_error(test_y, y_pred1))
#       5 print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(test_y, y_pred1)))
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     176     """
#     177     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 178         y_true, y_pred, multioutput)
#     179     check_consistent_length(y_true, y_pred, sample_weight)
#     180     output_errors = np.average(np.abs(y_pred - y_true),
#
# ...
